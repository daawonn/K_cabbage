# %%
# conda install -c conda-forge tensorflow=1.15

# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv

# %%
data = read_csv('price data.csv', sep=',')

# %%
model = tf.global_variables_initializer();

# %%
xy = np.array(data, dtype=np.float32)

# %%
# 4개의 변인을 입력을 받습니다.
x_data = xy[:, 1:-1]

# %%
# 가격 값을 입력 받습니다.
y_data = xy[:, [-1]]

# %%
# 플레이스 홀더를 설정합니다.
X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
# y = wX+b
W = tf.Variable(tf.random_normal([4, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 가설을 설정합니다. y = wX+b
# tensorflow 행별곱 합수 matmul
hypothesis = tf.matmul(X, W) + b

# %%
# 비용 함수를 설정합니다. (예측값 - 실제값)제곱의 평균
# reduce_mean은 특정 차원을 제거하고 평균을 구한다.
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 최적화 함수를 설정합니다.
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
train = optimizer.minimize(cost)

# %%
# 세션을 생성합니다.
sess = tf.Session()

# %%
# 글로벌 변수를 초기화합니다.
sess.run(tf.global_variables_initializer())

# %%
# 학습을 수행합니다.
for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 배추 가격: ", hypo_[0])
# Out:
# # 0  손실 비용:  12447417.0
# - 배추 가격:  [-19.948656]
# # 500  손실 비용:  4211342.5
# - 배추 가격:  [-288.65363]
# # 1000  손실 비용:  3800438.8
# - 배추 가격:  [22.785706]
# # 1500  손실 비용:  3479830.0
# - 배추 가격:  [306.368]
# # 2000  손실 비용:  3227854.8
# - 배추 가격:  [558.2934]
# # 2500  손실 비용:  3029288.8
# - 배추 가격:  [782.09644]
# # 3000  손실 비용:  2872537.5
# - 배추 가격:  [980.9723]
# # 3500  손실 비용:  2748648.8
# - 배추 가격:  [1157.74]
# # 4000  손실 비용:  2650655.2
# - 배추 가격:  [1314.8855]
# # 4500  손실 비용:  2573098.8
# - 배추 가격:  [1454.6077]
# # 5000  손실 비용:  2511687.8
# - 배추 가격:  [1578.8531]
# # 5500  손실 비용:  2463040.5
# - 배추 가격:  [1689.3474]
# # 6000  손실 비용:  2424486.0
# - 배추 가격:  [1787.6189]
# # 6500  손실 비용:  2393918.2
# - 배추 가격:  [1875.0266]
# # 7000  손실 비용:  2369666.2
# - 배추 가격:  [1952.7755]
# # 7500  손실 비용:  2350414.8
# - 배추 가격:  [2021.9342]
# # 8000  손실 비용:  2335119.2
# - 배추 가격:  [2083.4548]
# # 8500  손실 비용:  2322953.0
# - 배추 가격:  [2138.183]
# # 9000  손실 비용:  2313265.5
# - 배추 가격:  [2186.8696]
# # 9500  손실 비용:  2305538.0
# - 배추 가격:  [2230.1826]
# # 10000  손실 비용:  2299363.5
# - 배추 가격:  [2268.7163]
# # 10500  손실 비용:  2294417.2
# - 배추 가격:  [2302.9976]
# # 11000  손실 비용:  2290442.8
# - 배추 가격:  [2333.497]
# # 11500  손실 비용:  2287236.5
# - 배추 가격:  [2360.6326]
# # 12000  손실 비용:  2284640.5
# - 배추 가격:  [2384.7754]
# # 12500  손실 비용:  2282525.5
# - 배추 가격:  [2406.2563]
# # 13000  손실 비용:  2280792.8
# - 배추 가격:  [2425.3677]
# # 13500  손실 비용:  2279362.2
# - 배추 가격:  [2442.3728]
# # 14000  손실 비용:  2278170.0
# - 배추 가격:  [2581.7368]
# # 58000  손실 비용:  2250383.0
# - 배추 가격:  [2581.7847]
# # 58500  손실 비용:  2250115.5
# - 배추 가격:  [2581.8328]
# # 59000  손실 비용:  2249848.8
# - 배추 가격:  [2581.8762]
# # 59500  손실 비용:  2249582.2
# - 배추 가격:  [2581.9229]
# # 60000  손실 비용:  2249316.8
# - 배추 가격:  [2581.9663]
# # 60500  손실 비용:  2249049.8
# - 배추 가격:  [2581.9995]
# # 61000  손실 비용:  2248784.5
# - 배추 가격:  [2582.033]
# # 61500  손실 비용:  2248517.8
# - 배추 가격:  [2582.0657]
# # 62000  손실 비용:  2248252.0
# - 배추 가격:  [2582.1]
# # 62500  손실 비용:  2247985.8
# - 배추 가격:  [2582.1333]
# # 63000  손실 비용:  2247720.2
# - 배추 가격:  [2582.182]
# # 63500  손실 비용:  2247454.5
# - 배추 가격:  [2582.2356]
# # 64000  손실 비용:  2247189.2
# - 배추 가격:  [2582.2893]
# # 64500  손실 비용:  2246923.8
# - 배추 가격:  [2582.3433]
# # 65000  손실 비용:  2246658.8
# - 배추 가격:  [2582.3972]
# # 65500  손실 비용:  2246394.5
# - 배추 가격:  [2582.451]
# # 66000  손실 비용:  2246129.5
# - 배추 가격:  [2582.5022]
# # 66500  손실 비용:  2245864.8
# - 배추 가격:  [2582.5532]
# # 67000  손실 비용:  2245599.5
# - 배추 가격:  [2582.5945]
# # 67500  손실 비용:  2245334.8
# - 배추 가격:  [2582.6272]
# # 68000  손실 비용:  2245070.0
# - 배추 가격:  [2582.6604]
# # 68500  손실 비용:  2244806.5
# - 배추 가격:  [2582.6946]
# # 69000  손실 비용:  2244541.5
# - 배추 가격:  [2582.7285]
# # 69500  손실 비용:  2244277.5
# - 배추 가격:  [2582.762]
# # 70000  손실 비용:  2244014.0
# - 배추 가격:  [2582.796]
# # 70500  손실 비용:  2243749.2
# - 배추 가격:  [2582.829]
# # 71000  손실 비용:  2243485.8
# - 배추 가격:  [2582.864]
# # 71500  손실 비용:  2243222.2
# - 배추 가격:  [2582.8972]
# # 72000  손실 비용:  2242959.0
# - 배추 가격:  [2582.9316]
# # 72500  손실 비용:  2242695.5
# - 배추 가격:  [2582.9656]
# # 73000  손실 비용:  2242432.5
# - 배추 가격:  [2582.9978]
# # 73500  손실 비용:  2242170.5
# - 배추 가격:  [2583.0215]
# # 74000  손실 비용:  2241910.0
# - 배추 가격:  [2583.0435]
# # 74500  손실 비용:  2241649.0
# - 배추 가격:  [2583.0654]
# # 75000  손실 비용:  2241388.5
# - 배추 가격:  [2583.088]
# # 75500  손실 비용:  2241128.2
# - 배추 가격:  [2583.1094]
# # 76000  손실 비용:  2240868.5
# - 배추 가격:  [2583.126]
# # 76500  손실 비용:  2240608.2
# - 배추 가격:  [2583.1428]
# # 77000  손실 비용:  2240348.0
# - 배추 가격:  [2583.1597]
# # 77500  손실 비용:  2240087.5
# - 배추 가격:  [2583.1765]
# # 78000  손실 비용:  2239828.8
# - 배추 가격:  [2583.193]
# # 78500  손실 비용:  2239568.8
# - 배추 가격:  [2583.2097]
# # 79000  손실 비용:  2239308.8
# - 배추 가격:  [2583.2266]
# # 79500  손실 비용:  2239049.5
# - 배추 가격:  [2583.2388]
# # 80000  손실 비용:  2238790.0
# - 배추 가격:  [2583.2498]
# # 80500  손실 비용:  2238531.0
# - 배추 가격:  [2583.2612]
# # 81000  손실 비용:  2238271.0
# - 배추 가격:  [2583.2727]
# # 81500  손실 비용:  2238011.5
# - 배추 가격:  [2583.2844]
# # 82000  손실 비용:  2237753.8
# - 배추 가격:  [2583.2957]
# # 82500  손실 비용:  2237494.5
# - 배추 가격:  [2583.3071]
# # 83000  손실 비용:  2237235.8
# - 배추 가격:  [2583.3186]
# # 83500  손실 비용:  2236976.2
# - 배추 가격:  [2583.33]
# # 84000  손실 비용:  2236717.8
# - 배추 가격:  [2583.34]
# # 84500  손실 비용:  2236459.8
# - 배추 가격:  [2583.3467]
# # 85000  손실 비용:  2236200.8
# - 배추 가격:  [2583.3528]
# # 85500  손실 비용:  2235942.5
# - 배추 가격:  [2583.3591]
# # 86000  손실 비용:  2235685.2
# - 배추 가격:  [2583.365]
# # 86500  손실 비용:  2235426.2
# - 배추 가격:  [2583.371]
# # 87000  손실 비용:  2235169.0
# - 배추 가격:  [2583.3774]
# # 87500  손실 비용:  2234910.2
# - 배추 가격:  [2583.4065]
# # 88000  손실 비용:  2234653.0
# - 배추 가격:  [2583.4414]
# # 88500  손실 비용:  2234395.8
# - 배추 가격:  [2583.4756]
# # 89000  손실 비용:  2234138.0
# - 배추 가격:  [2583.5103]
# # 89500  손실 비용:  2233881.0
# - 배추 가격:  [2583.5442]
# # 90000  손실 비용:  2233623.5
# - 배추 가격:  [2583.5784]
# # 90500  손실 비용:  2233367.8
# - 배추 가격:  [2583.6125]
# # 91000  손실 비용:  2233112.2
# - 배추 가격:  [2583.646]
# # 91500  손실 비용:  2232858.0
# - 배추 가격:  [2583.68]
# # 92000  손실 비용:  2232604.0
# - 배추 가격:  [2583.7146]
# # 92500  손실 비용:  2232350.2
# - 배추 가격:  [2583.7483]
# # 93000  손실 비용:  2232096.5
# - 배추 가격:  [2583.7825]
# # 93500  손실 비용:  2231841.5
# - 배추 가격:  [2583.816]
# # 94000  손실 비용:  2231587.5
# - 배추 가격:  [2583.8503]
# # 94500  손실 비용:  2231334.2
# - 배추 가격:  [2583.884]
# # 95000  손실 비용:  2231080.2
# - 배추 가격:  [2583.9192]
# # 95500  손실 비용:  2230828.0
# - 배추 가격:  [2583.9526]
# # 96000  손실 비용:  2230573.8
# - 배추 가격:  [2583.987]
# # 96500  손실 비용:  2230320.5
# - 배추 가격:  [2584.0222]
# # 97000  손실 비용:  2230067.8
# - 배추 가격:  [2584.0554]
# # 97500  손실 비용:  2229814.0
# - 배추 가격:  [2584.0906]
# # 98000  손실 비용:  2229561.5
# - 배추 가격:  [2584.1262]
# # 98500  손실 비용:  2229308.5
# - 배추 가격:  [2584.1604]
# # 99000  손실 비용:  2229055.0
# - 배추 가격:  [2584.1943]
# # 99500  손실 비용:  2228803.0
# - 배추 가격:  [2584.23]
# # 100000  손실 비용:  2228551.5
# - 배추 가격:  [2584.264]

# %%
# 학습된 모델을 저장합니다.
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')
# Out:
# 학습된 모델을 저장했습니다.
