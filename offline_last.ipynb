# %%
# conda install -c conda-forge tensorflow=1.15

# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
data = read_csv('price_data.csv', sep=',')

# %%
data = data[data.avgPrice < 6500]
data
# Out:
#           year  avgTemp  minTemp  maxTemp  rainFall  avgPrice
# 0     20100101     -4.9    -11.0      0.9       0.0      2123
# 1     20100102     -3.1     -5.5      5.5       0.8      2123
# 2     20100103     -2.9     -6.9      1.4       0.0      2123
# 3     20100104     -1.8     -5.1      2.2       5.9      2020
# 4     20100105     -5.2     -8.7     -1.8       0.7      2060
# ...        ...      ...      ...      ...       ...       ...
# 2917  20171227     -3.9     -8.0      0.7       0.0      2865
# 2918  20171228     -1.5     -6.9      3.7       0.0      2884
# 2919  20171229      2.9     -2.1      8.0       0.0      2901
# 2920  20171230      2.9     -1.6      7.1       0.6      2901
# 2921  20171231      2.1     -2.0      5.8       0.4      2901
#
# [2825 rows x 6 columns]

# %%
data['year_1'] = data['year'].apply(lambda x: str(x)[:4])
data['month'] = data['year'].apply(lambda x: str(x)[4:6])
data.head()
# Out:
#        year  avgTemp  minTemp  maxTemp  rainFall  avgPrice year_1 month
# 0  20100101     -4.9    -11.0      0.9       0.0      2123   2010    01
# 1  20100102     -3.1     -5.5      5.5       0.8      2123   2010    01
# 2  20100103     -2.9     -6.9      1.4       0.0      2123   2010    01
# 3  20100104     -1.8     -5.1      2.2       5.9      2020   2010    01
# 4  20100105     -5.2     -8.7     -1.8       0.7      2060   2010    01

# %%
data.tail()
# Out:
#           year  avgTemp  minTemp  maxTemp  rainFall  avgPrice year_1 month
# 2917  20171227     -3.9     -8.0      0.7       0.0      2865   2017    12
# 2918  20171228     -1.5     -6.9      3.7       0.0      2884   2017    12
# 2919  20171229      2.9     -2.1      8.0       0.0      2901   2017    12
# 2920  20171230      2.9     -1.6      7.1       0.6      2901   2017    12
# 2921  20171231      2.1     -2.0      5.8       0.4      2901   2017    12

# %%
means = data.groupby([data['year_1'],data['month']],as_index=False).mean()
means
# Out:
#    year_1 month        year    avgTemp    minTemp    maxTemp  rainFall  \
# 0    2010    01  20100116.0  -1.851613  -6.635484   3.577419  0.967742
# 1    2010    02  20100214.5   2.353571  -1.985714   7.203571  2.932143
# 2    2010    03  20100316.0   5.458065   1.125806   9.880645  2.874194
# 3    2010    04  20100415.5   9.863333   4.493333  15.456667  2.970000
# 4    2010    05  20100516.0  17.087097  11.538710  23.041935  4.003226
# ..    ...   ...         ...        ...        ...        ...       ...
# 90   2017    08  20170810.5  26.045000  22.845000  30.280000  8.465000
# 91   2017    09  20170922.5  19.956250  14.893750  25.843750  1.687500
# 92   2017    10  20171016.0  15.312903  10.803226  20.967742  2.170968
# 93   2017    11  20171115.5   6.803333   1.260000  12.923333  0.413333
# 94   2017    12  20171216.0  -0.164516  -4.961290   4.996774  0.709677
#
#        avgPrice
# 0   2169.612903
# 1   3082.857143
# 2   4414.193548
# 3   5850.000000
# 4   4329.000000
# ..          ...
# 90  5549.300000
# 91  6241.437500
# 92  4387.774194
# 93  2580.566667
# 94  2739.096774
#
# [95 rows x 8 columns]

# %%
month_price = means[['year_1','month','avgTemp','minTemp','maxTemp','rainFall','year','avgPrice']]
month_price = month_price[month_price.columns[6:8]]
month_price
# Out:
#           year     avgPrice
# 0   20100116.0  2169.612903
# 1   20100214.5  3082.857143
# 2   20100316.0  4414.193548
# 3   20100415.5  5850.000000
# 4   20100516.0  4329.000000
# ..         ...          ...
# 90  20170810.5  5549.300000
# 91  20170922.5  6241.437500
# 92  20171016.0  4387.774194
# 93  20171115.5  2580.566667
# 94  20171216.0  2739.096774
#
# [95 rows x 2 columns]

# %%
month_price['year_2'] = month_price['year'].apply(lambda x: str(x)[0:6])
month_price['avgPrice_2'] = month_price['avgPrice']
month_price = month_price[month_price.columns[2:4]]
month_price
# Out:
#     year_2   avgPrice_2
# 0   201001  2169.612903
# 1   201002  3082.857143
# 2   201003  4414.193548
# 3   201004  5850.000000
# 4   201005  4329.000000
# ..     ...          ...
# 90  201708  5549.300000
# 91  201709  6241.437500
# 92  201710  4387.774194
# 93  201711  2580.566667
# 94  201712  2739.096774
#
# [95 rows x 2 columns]

# %%
data['year_2'] = data['year'].apply(lambda x: str(x)[0:6])
data.head()
# Out:
#        year  avgTemp  minTemp  maxTemp  rainFall  avgPrice year_1 month  \
# 0  20100101     -4.9    -11.0      0.9       0.0      2123   2010    01
# 1  20100102     -3.1     -5.5      5.5       0.8      2123   2010    01
# 2  20100103     -2.9     -6.9      1.4       0.0      2123   2010    01
# 3  20100104     -1.8     -5.1      2.2       5.9      2020   2010    01
# 4  20100105     -5.2     -8.7     -1.8       0.7      2060   2010    01
#
#    year_2
# 0  201001
# 1  201001
# 2  201001
# 3  201001
# 4  201001

# %%
import pandas as pd

# %%
last = pd.merge(data,month_price,how='outer')

# %%
last.shape
# Out:
# (2825, 10)

# %%
last_2 = last.drop(['avgPrice','year_1','month','year_2'],axis=1)
last_2.head()
# Out:
#        year  avgTemp  minTemp  maxTemp  rainFall   avgPrice_2
# 0  20100101     -4.9    -11.0      0.9       0.0  2169.612903
# 1  20100102     -3.1     -5.5      5.5       0.8  2169.612903
# 2  20100103     -2.9     -6.9      1.4       0.0  2169.612903
# 3  20100104     -1.8     -5.1      2.2       5.9  2169.612903
# 4  20100105     -5.2     -8.7     -1.8       0.7  2169.612903

# %%
minmax = MinMaxScaler()

# %%
xy = np.array(last_2, dtype=np.float32)
yx = np.array(last_2.iloc[:, [-1]], dtype=np.float32 )

# %%
xy = minmax.fit_transform(xy)

# %%
model = tf.global_variables_initializer();

# %%
# 4개의 변인을 입력을 받습니다.
x_data = xy[:, 1:-1]

# %%
# 가격 값을 입력 받습니다.
y_data = yx

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,y_data,random_state=0)

# %%
# 플레이스 홀더를 설정합니다.
X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
# y = wX+b
W = tf.Variable(tf.random_normal([4, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 가설을 설정합니다. y = wX+b
# tensorflow 행렬곱 합수 matmul
hypothesis = tf.matmul(X, W) + b
# hypothesis = tf.nn.softmax(tf.matmul(X, W) + b)

# %%
# 비용 함수를 설정합니다. (예측값 - 실제값)제곱의 평균
# reduce_mean은 특정 차원을 제거하고 평균을 구한다.
cost = tf.reduce_mean(tf.square(hypothesis - Y))
correct_prediction = tf.equal(tf.argmax(hypothesis,1),tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

# %%
mae = tf.reduce_mean(tf.abs(hypothesis - Y))

# %%
# 최적화 함수를 설정합니다.
optimizer = tf.train.MomentumOptimizer(learning_rate=0.0005,momentum=0.9)
train = optimizer.minimize(cost)

# %%
# 세션을 생성합니다.
sess = tf.Session()

# %%
# 글로벌 변수를 초기화합니다.
sess.run(tf.global_variables_initializer())

# %%
# 학습을 수행합니다.
for step in range(100001):
    mae_, hypo_, _ = sess.run([mae, hypothesis, train], feed_dict={X: X_train, Y: y_train})
    if step % 1000 == 0:
        print("#", step, " 손실 비용: ", mae_)
        print("- 배추 가격: ", hypo_[0])
        
# 손실비용 대신 MAE(Mean absolute error) 사용해보기
# Out:
# # 0  손실 비용:  3112.0505
# - 배추 가격:  [0.6897178]
# # 1000  손실 비용:  3102.1248
# - 배추 가격:  [12.997787]
# # 2000  손실 비용:  3092.1118
# - 배추 가격:  [25.417404]
# # 3000  손실 비용:  3082.0972
# - 배추 가격:  [37.836937]
# # 4000  손실 비용:  3072.0835
# - 배추 가격:  [50.25524]
# # 5000  손실 비용:  3062.071
# - 배추 가격:  [62.67344]
# # 6000  손실 비용:  3052.0574
# - 배추 가격:  [75.09211]
# # 7000  손실 비용:  3042.0437
# - 배추 가격:  [87.51262]
# # 8000  손실 비용:  3032.0273
# - 배추 가격:  [99.93358]
# # 9000  손실 비용:  3022.0132
# - 배추 가격:  [112.354546]
# # 10000  손실 비용:  3011.9973
# - 배추 가격:  [124.77551]
# # 11000  손실 비용:  3001.9822
# - 배추 가격:  [137.19647]
# # 12000  손실 비용:  2991.9678
# - 배추 가격:  [149.616]
# # 13000  손실 비용:  2981.9546
# - 배추 가격:  [162.03384]
# # 14000  손실 비용:  2971.944
# - 배추 가격:  [174.44928]
# # 15000  손실 비용:  2961.934
# - 배추 가격:  [186.86469]
# # 16000  손실 비용:  2951.9236
# - 배추 가격:  [199.28012]
# # 17000  손실 비용:  2941.9126
# - 배추 가격:  [211.69554]
# # 18000  손실 비용:  2931.903
# - 배추 가격:  [224.11096]
# # 19000  손실 비용:  2921.8918
# - 배추 가격:  [236.5264]
# # 20000  손실 비용:  2911.883
# - 배추 가격:  [248.94183]
# # 21000  손실 비용:  2901.8713
# - 배추 가격:  [261.35724]
# # 22000  손실 비용:  2891.8596
# - 배추 가격:  [273.7727]
# # 23000  손실 비용:  2881.8472
# - 배추 가격:  [286.1911]
# # 24000  손실 비용:  2871.8352
# - 배추 가격:  [298.60962]
# # 25000  손실 비용:  2861.823
# - 배추 가격:  [311.0281]
# # 26000  손실 비용:  2851.8057
# - 배추 가격:  [323.45087]
# # 27000  손실 비용:  2841.7854
# - 배추 가격:  [335.877]
# # 28000  손실 비용:  2831.765
# - 배추 가격:  [348.3031]
# # 29000  손실 비용:  2821.7449
# - 배추 가격:  [360.72925]
# # 30000  손실 비용:  2811.7246
# - 배추 가격:  [373.1554]
# # 31000  손실 비용:  2801.7043
# - 배추 가격:  [385.58154]
# # 32000  손실 비용:  2791.683
# - 배추 가격:  [398.0077]
# # 33000  손실 비용:  2781.6628
# - 배추 가격:  [410.43384]
# # 34000  손실 비용:  2771.6428
# - 배추 가격:  [422.85992]
# # 35000  손실 비용:  2761.623
# - 배추 가격:  [435.28607]
# # 36000  손실 비용:  2751.6016
# - 배추 가격:  [447.71222]
# # 37000  손실 비용:  2741.582
# - 배추 가격:  [460.13837]
# # 38000  손실 비용:  2731.5613
# - 배추 가격:  [472.5645]
# # 39000  손실 비용:  2721.5417
# - 배추 가격:  [484.99066]

# %%
# 글로벌 변수를 초기화합니다.
sess.run(tf.global_variables_initializer())

# %%
correct_prediction = tf.equal(tf.argmax(hypothesis,1),tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

# %%
for step in range(100001):
    mae_, hypo_,accuracy_, _ = sess.run([mae, hypothesis, accuracy, train], feed_dict={X: X_test, Y: y_test})
    if step % 1000 == 0:
        print("#", step, " 손실 비용: ", mae_)        
        print("- 배추 가격: ", hypo_[0])
        if step == 1000:
            print("@", '정확도', accuracy_)
# Out:
# # 0  손실 비용:  3281.197
# - 배추 가격:  [1.0603071]
# # 1000  손실 비용:  1026.4772
# - 배추 가격:  [2472.4446]
# @ 정확도 1.0
# # 2000  손실 비용:  1011.7071
# - 배추 가격:  [2682.448]
# # 3000  손실 비용:  1006.7701
# - 배추 가격:  [2778.0671]
# # 4000  손실 비용:  1004.34644
# - 배추 가격:  [2821.3896]
# # 5000  손실 비용:  1003.0683
# - 배추 가격:  [2840.7886]
# # 6000  손실 비용:  1002.2327
# - 배추 가격:  [2849.229]
# # 7000  손실 비용:  1001.7071
# - 배추 가격:  [2852.6382]
# # 8000  손실 비용:  1001.2931
# - 배추 가격:  [2853.726]
# # 9000  손실 비용:  1000.9403
# - 배추 가격:  [2853.739]
# # 10000  손실 비용:  1000.6297
# - 배추 가격:  [2853.2458]
# # 11000  손실 비용:  1000.3414
# - 배추 가격:  [2852.5132]
# # 12000  손실 비용:  1000.06714
# - 배추 가격:  [2851.637]
# # 13000  손실 비용:  999.80316
# - 배추 가격:  [2850.7412]
# # 14000  손실 비용:  999.54913
# - 배추 가격:  [2849.769]
# # 15000  손실 비용:  999.30457
# - 배추 가격:  [2848.7676]
# # 16000  손실 비용:  999.06866
# - 배추 가격:  [2847.7468]
# # 17000  손실 비용:  998.83966
# - 배추 가격:  [2846.7285]
# # 18000  손실 비용:  998.6188
# - 배추 가격:  [2845.7148]
# # 19000  손실 비용:  998.4038
# - 배추 가격:  [2844.7068]
# # 20000  손실 비용:  998.19684
# - 배추 가격:  [2843.7039]
# # 21000  손실 비용:  998.0017
# - 배추 가격:  [2842.706]
# # 22000  손실 비용:  997.81244
# - 배추 가격:  [2841.7117]
# # 23000  손실 비용:  997.6284
# - 배추 가격:  [2840.7058]
# # 24000  손실 비용:  997.4501
# - 배추 가격:  [2839.6956]
# # 25000  손실 비용:  997.2769
# - 배추 가격:  [2838.689]
# # 26000  손실 비용:  997.1085
# - 배추 가격:  [2837.6904]
# # 27000  손실 비용:  996.9443
# - 배추 가격:  [2836.6985]
# # 28000  손실 비용:  996.78564
# - 배추 가격:  [2835.7166]
# # 29000  손실 비용:  996.62994
# - 배추 가격:  [2834.742]
# # 30000  손실 비용:  996.4782
# - 배추 가격:  [2833.7715]
# # 31000  손실 비용:  996.33057
# - 배추 가격:  [2832.8042]
# # 32000  손실 비용:  996.18713
# - 배추 가격:  [2831.839]
# # 33000  손실 비용:  996.0465
# - 배추 가격:  [2830.8738]
# # 34000  손실 비용:  995.91034
# - 배추 가격:  [2829.9292]
# # 35000  손실 비용:  995.77704
# - 배추 가격:  [2829.017]
# # 36000  손실 비용:  995.64655
# - 배추 가격:  [2828.1243]
# # 37000  손실 비용:  995.5188
# - 배추 가격:  [2827.243]
# # 38000  손실 비용:  995.39636
# - 배추 가격:  [2826.374]
# # 39000  손실 비용:  995.2783
# - 배추 가격:  [2825.5178]
# # 40000  손실 비용:  995.1629
# - 배추 가격:  [2824.6768]
# # 41000  손실 비용:  995.05054
# - 배추 가격:  [2823.8489]
# # 42000  손실 비용:  994.94
# - 배추 가격:  [2823.0337]
# # 43000  손실 비용:  994.832
# - 배추 가격:  [2822.2312]
# # 44000  손실 비용:  994.7299
# - 배추 가격:  [2821.4375]
# # 45000  손실 비용:  994.6304
# - 배추 가격:  [2820.655]
# # 46000  손실 비용:  994.5336
# - 배추 가격:  [2819.8752]
# # 47000  손실 비용:  994.44073
# - 배추 가격:  [2819.0942]
# # 48000  손실 비용:  994.3503
# - 배추 가격:  [2818.3137]
# # 49000  손실 비용:  994.26306
# - 배추 가격:  [2817.5583]
# # 50000  손실 비용:  994.17645
# - 배추 가격:  [2816.8396]
# # 51000  손실 비용:  994.0935
# - 배추 가격:  [2816.14]
# # 52000  손실 비용:  994.01495
# - 배추 가격:  [2815.4497]
# # 53000  손실 비용:  993.9381
# - 배추 가격:  [2814.7712]
# # 54000  손실 비용:  993.86304
# - 배추 가격:  [2814.1099]
# # 55000  손실 비용:  993.7893
# - 배추 가격:  [2813.4556]
# # 56000  손실 비용:  993.7175
# - 배추 가격:  [2812.815]
# # 57000  손실 비용:  993.65045
# - 배추 가격:  [2812.1877]
# # 58000  손실 비용:  993.58484
# - 배추 가격:  [2811.567]
# # 59000  손실 비용:  993.52
# - 배추 가격:  [2810.9568]
# # 60000  손실 비용:  993.4575
# - 배추 가격:  [2810.352]
# # 61000  손실 비용:  993.395
# - 배추 가격:  [2809.7446]
# # 62000  손실 비용:  993.3374
# - 배추 가격:  [2809.1387]
# # 63000  손실 비용:  993.2843
# - 배추 가격:  [2808.5364]
# # 64000  손실 비용:  993.23254
# - 배추 가격:  [2807.9746]
# # 65000  손실 비용:  993.1811
# - 배추 가격:  [2807.4285]
# # 66000  손실 비용:  993.1305
# - 배추 가격:  [2806.9004]
# # 67000  손실 비용:  993.081
# - 배추 가격:  [2806.3787]
# # 68000  손실 비용:  993.0325
# - 배추 가격:  [2805.8674]
# # 69000  손실 비용:  992.98486
# - 배추 가격:  [2805.3699]
# # 70000  손실 비용:  992.9381
# - 배추 가격:  [2804.8772]
# # 71000  손실 비용:  992.89233
# - 배추 가격:  [2804.3928]
# # 72000  손실 비용:  992.8471
# - 배추 가격:  [2803.9243]
# # 73000  손실 비용:  992.8038
# - 배추 가격:  [2803.4644]
# # 74000  손실 비용:  992.7612
# - 배추 가격:  [2803.008]
# # 75000  손실 비용:  992.71954
# - 배추 가격:  [2802.5605]
# # 76000  손실 비용:  992.6786
# - 배추 가격:  [2802.1204]
# # 77000  손실 비용:  992.638
# - 배추 가격:  [2801.6848]
# # 78000  손실 비용:  992.5985
# - 배추 가격:  [2801.2498]
# # 79000  손실 비용:  992.55975
# - 배추 가격:  [2800.8145]
# # 80000  손실 비용:  992.5216
# - 배추 가격:  [2800.379]
# # 81000  손실 비용:  992.4857
# - 배추 가격:  [2799.9543]
# # 82000  손실 비용:  992.44965
# - 배추 가격:  [2799.561]
# # 83000  손실 비용:  992.4138
# - 배추 가격:  [2799.1812]
# # 84000  손실 비용:  992.3793
# - 배추 가격:  [2798.8098]
# # 85000  손실 비용:  992.3453
# - 배추 가격:  [2798.446]
# # 86000  손실 비용:  992.312
# - 배추 가격:  [2798.0906]
# # 87000  손실 비용:  992.2797
# - 배추 가격:  [2797.7405]
# # 88000  손실 비용:  992.2475
# - 배추 가격:  [2797.3982]
# # 89000  손실 비용:  992.2161
# - 배추 가격:  [2797.0613]
# # 90000  손실 비용:  992.18536
# - 배추 가격:  [2796.7324]
# # 91000  손실 비용:  992.1559
# - 배추 가격:  [2796.4077]
# # 92000  손실 비용:  992.12634
# - 배추 가격:  [2796.0918]
# # 93000  손실 비용:  992.0979
# - 배추 가격:  [2795.788]
# # 94000  손실 비용:  992.0697
# - 배추 가격:  [2795.4875]
# # 95000  손실 비용:  992.0422
# - 배추 가격:  [2795.1924]
# # 96000  손실 비용:  992.0151
# - 배추 가격:  [2794.901]
# # 97000  손실 비용:  991.9888
# - 배추 가격:  [2794.612]
# # 98000  손실 비용:  991.9628
# - 배추 가격:  [2794.3367]
# # 99000  손실 비용:  991.9371
# - 배추 가격:  [2794.0652]
# # 100000  손실 비용:  991.9111
# - 배추 가격:  [2793.7942]

# %%
# 학습된 모델을 저장합니다.
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')
# Out:
# 학습된 모델을 저장했습니다.
